# %%
# Streaming Hotel/Weather Aggregation with Auto Loader
# ----------------------------------------
# 1) Imports & Helpers
# ----------------------------------------
from pyspark.sql.functions import (
    year, month, dayofmonth, col, to_date,
    approx_count_distinct, avg, max, min, round, desc
)
from pyspark.sql.types import (
    StructType, StringType, DoubleType, TimestampType
)

# %%
# ----------------------------------------
# 2) Read Secrets & Configure Spark
# ----------------------------------------
storage_account = dbutils.secrets.get("streaming", "AZURE_STORAGE_ACCOUNT_NAME")
storage_key     = dbutils.secrets.get("streaming", "AZURE_STORAGE_ACCOUNT_KEY")
container       = dbutils.secrets.get("streaming", "AZURE_CONTAINER_NAME")

config = {
    "storage_account": storage_account,
    "storage_key": storage_key,
    "container": container
}

# tell Spark how to authenticate to your Blob storage
spark.conf.set(
    f"fs.azure.account.key.{storage_account}.blob.core.windows.net",
    storage_key
)

# %%
# ----------------------------------------
# 3) Build Paths
# ----------------------------------------
container_root    = f"wasbs://{container}@{storage_account}.blob.core.windows.net/"
input_path        = container_root
checkpoint_prefix = "dbfs:/checkpoints/hotel-weather/"
console_ckpt      = checkpoint_prefix + "console-hotel-weather-agg"
delta_ckpt        = checkpoint_prefix + "delta-agg-city"
delta_path        = container_root + "delta/agg_city"

# ----------------------------------------
# Cleanup any old checkpoints (on DBFS)
# ----------------------------------------
for path in (console_ckpt, delta_ckpt):
    dbutils.fs.rm(path, recurse=True)
    print(f"Deleted old checkpoint directory (if existed): {path}")

# %%
# ----------------------------------------
# 4) Sanity-Check Your Paths
# ----------------------------------------
print("Container root listing:")
display(dbutils.fs.ls(container_root))
print("Input path listing:")
display(dbutils.fs.ls(input_path))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>wasbs://[REDACTED]@[REDACTED].blob.core.windows.net/year=2016/</td><td>year=2016/</td><td>0</td><td>0</td></tr><tr><td>wasbs://[REDACTED]@[REDACTED].blob.core.windows.net/year=2017/</td><td>year=2017/</td><td>0</td><td>0</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>wasbs://[REDACTED]@[REDACTED].blob.core.windows.net/year=2016/</td><td>year=2016/</td><td>0</td><td>0</td></tr><tr><td>wasbs://[REDACTED]@[REDACTED].blob.core.windows.net/year=2017/</td><td>year=2017/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
# ----------------------------------------
# 5) Define Schema & Start Auto Loader
# ----------------------------------------
schema = (
    StructType()
      .add("address",    StringType())
      .add("avg_tmpr_c", DoubleType())
      .add("avg_tmpr_f", DoubleType())
      .add("city",       StringType())
      .add("country",    StringType())
      .add("geoHash",    StringType())
      .add("id",         StringType())
      .add("latitude",   DoubleType())
      .add("longitude",  DoubleType())
      .add("name",       StringType())
      .add("wthr_date",  StringType())
      .add("wthr_year",  StringType())
      .add("wthr_month",  StringType())
      .add("wthr_day",  StringType())
)

# %%
raw_stream = (
    spark.readStream
      .format("cloudFiles")
      .option("cloudFiles.format", "parquet")
      .option("header", "true")
      .schema(hotel_schema)
      .load(input_path)
)
print("Raw stream schema:")
raw_stream.printSchema()

# %%
display(raw_stream)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>address</th><th>avg_tmpr_c</th><th>avg_tmpr_f</th><th>city</th><th>country</th><th>geoHash</th><th>id</th><th>latitude</th><th>longitude</th><th>name</th><th>wthr_date</th><th>wthr_year</th><th>wthr_month</th><th>wthr_day</th></tr></thead><tbody><tr><td>Travelodge</td><td>9.2</td><td>48.6</td><td>Oswego</td><td>US</td><td>dr9x</td><td>25769803777</td><td>43.45161</td><td>-76.53235</td><td>309 W Seneca St</td><td>2016-10-10</td><td>null</td><td>null</td><td>null</td></tr><tr><td>Quality Inn & Suites - Riverfront</td><td>9.2</td><td>48.6</td><td>Oswego</td><td>US</td><td>dr9x</td><td>369367187459</td><td>43.45818526</td><td>-76.50861875</td><td>70 E 1st St</td><td>2016-10-10</td><td>null</td><td>null</td><td>null</td></tr><tr><td>Country Inn & Suites By Carlson</td><td>15.8</td><td>60.5</td><td>Clinton</td><td>US</td><td>dnkj</td><td>1047972020226</td><td>36.16315</td><td>-84.08504</td><td>710 Park Pl</td><td>2016-10-10</td><td>null</td><td>null</td><td>null</td></tr><tr><td>Acorn Motor Inn</td><td>9.9</td><td>49.8</td><td>Oak Harbor</td><td>US</td><td>c28f</td><td>343597383685</td><td>48.288952</td><td>-122.657842</td><td>31530 State Route 20</td><td>2016-10-10</td><td>null</td><td>null</td><td>null</td></tr><tr><td>Econo Lodge St Robert</td><td>15.9</td><td>60.7</td><td>St. Robert</td><td>US</td><td>9ywr</td><td>876173328384</td><td>37.8228</td><td>-92.14079</td><td>309 Highway Z</td><td>2016-10-10</td><td>null</td><td>null</td><td>null</td></tr><tr><td>Hampton Inn-st Robert</td><td>15.9</td><td>60.7</td><td>Saint Robert</td><td>US</td><td>9ywr</td><td>3</td><td>37.82382</td><td>-92.149721</td><td>103 Saint Robert Plaza Dr</td><td>2016-10-10</td><td>null</td><td>null</td><td>null</td></tr><tr><td>The Montcalm Marble Arch</td><td>8.4</td><td>47.2</td><td>London</td><td>GB</td><td>gcpv</td><td>3143916060674</td><td>51.5150522</td><td>-0.159239</td><td>2 Wallenberg Place Westminster Borough London W1H 7TN United Kingdom</td><td>2016-10-10</td><td>null</td><td>null</td><td>null</td></tr><tr><td>DoubleTree by Hilton London West End</td><td>8.4</td><td>47.2</td><td>London</td><td>GB</td><td>gcpv</td><td>3221225472004</td><td>51.5201065</td><td>-0.1221393</td><td>92 Southampton Row Camden London WC1B 4BH United Kingdom</td><td>2016-10-10</td><td>null</td><td>null</td><td>null</td></tr><tr><td>Montcalm Royal London House City of London</td><td>8.4</td><td>47.2</td><td>London</td><td>GB</td><td>gcpv</td><td>3332894621696</td><td>51.5218066</td><td>-0.0856081</td><td>22 25 Finsbury Square City Islington London EC2A 1DX United Kingdom</td><td>2016-10-10</td><td>null</td><td>null</td><td>null</td></tr><tr><td>Radisson Blu Edwardian Berkshire</td><td>8.4</td><td>47.2</td><td>London</td><td>GB</td><td>gcpv</td><td>2508260900866</td><td>51.5146025</td><td>-0.1481978</td><td>350 Oxford Street Westminster Borough London W1C 1BY United Kingdom</td><td>2016-10-10</td><td>null</td><td>null</td><td>null</td></tr><tr><td>Great St Helen Hotel</td><td>8.4</td><td>47.2</td><td>London</td><td>GB</td><td>gcpv</td><td>2362232012803</td><td>51.5149583</td><td>-0.0823869</td><td>36 Great st Helens City of London London EC3A 6AP United Kingdom</td><td>2016-10-10</td><td>null</td><td>null</td><td>null</td></tr><tr><td>Norfolk Towers Paddington</td><td>8.4</td><td>47.2</td><td>Paddington</td><td>GB</td><td>gcpv</td><td>3358664425476</td><td>51.5162883</td><td>-0.1721078</td><td>34 Norfolk Place Paddington Westminster Borough London W2 1QW United Kingdom</td><td>2016-10-10</td><td>null</td><td>null</td><td>null</td></tr><tr><td>Ham Yard Hotel</td><td>8.4</td><td>47.2</td><td>London</td><td>GB</td><td>gcpv</td><td>2783138807814</td><td>51.511174</td><td>-0.1349904</td><td>One Ham Yard Westminster Borough London W1D 7DT United Kingdom</td><td>2016-10-10</td><td>null</td><td>null</td><td>null</td></tr><tr><td>The Bloomsbury Hotel</td><td>8.4</td> ...

# %%
# ----------------------------------------
# 6) Enrich with Timestamp, Date & Watermark
# ----------------------------------------
stream = (
    raw_stream
      .withColumn("wthr_date", col("wthr_date").cast(TimestampType()))
      .withColumn("date",      to_date(col("wthr_date")))
      .withWatermark("wthr_date", "1 day")  # handle up-to-1-day late data
)

# %%
display(stream)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>address</th><th>avg_tmpr_c</th><th>avg_tmpr_f</th><th>city</th><th>country</th><th>geoHash</th><th>id</th><th>latitude</th><th>longitude</th><th>name</th><th>wthr_date</th><th>wthr_year</th><th>wthr_month</th><th>wthr_day</th><th>date</th></tr></thead><tbody><tr><td>Travelodge</td><td>9.2</td><td>48.6</td><td>Oswego</td><td>US</td><td>dr9x</td><td>25769803777</td><td>43.45161</td><td>-76.53235</td><td>309 W Seneca St</td><td>2016-10-10T00:00:00Z</td><td>null</td><td>null</td><td>null</td><td>2016-10-10</td></tr><tr><td>Quality Inn & Suites - Riverfront</td><td>9.2</td><td>48.6</td><td>Oswego</td><td>US</td><td>dr9x</td><td>369367187459</td><td>43.45818526</td><td>-76.50861875</td><td>70 E 1st St</td><td>2016-10-10T00:00:00Z</td><td>null</td><td>null</td><td>null</td><td>2016-10-10</td></tr><tr><td>Country Inn & Suites By Carlson</td><td>15.8</td><td>60.5</td><td>Clinton</td><td>US</td><td>dnkj</td><td>1047972020226</td><td>36.16315</td><td>-84.08504</td><td>710 Park Pl</td><td>2016-10-10T00:00:00Z</td><td>null</td><td>null</td><td>null</td><td>2016-10-10</td></tr><tr><td>Acorn Motor Inn</td><td>9.9</td><td>49.8</td><td>Oak Harbor</td><td>US</td><td>c28f</td><td>343597383685</td><td>48.288952</td><td>-122.657842</td><td>31530 State Route 20</td><td>2016-10-10T00:00:00Z</td><td>null</td><td>null</td><td>null</td><td>2016-10-10</td></tr><tr><td>Econo Lodge St Robert</td><td>15.9</td><td>60.7</td><td>St. Robert</td><td>US</td><td>9ywr</td><td>876173328384</td><td>37.8228</td><td>-92.14079</td><td>309 Highway Z</td><td>2016-10-10T00:00:00Z</td><td>null</td><td>null</td><td>null</td><td>2016-10-10</td></tr><tr><td>Hampton Inn-st Robert</td><td>15.9</td><td>60.7</td><td>Saint Robert</td><td>US</td><td>9ywr</td><td>3</td><td>37.82382</td><td>-92.149721</td><td>103 Saint Robert Plaza Dr</td><td>2016-10-10T00:00:00Z</td><td>null</td><td>null</td><td>null</td><td>2016-10-10</td></tr><tr><td>The Montcalm Marble Arch</td><td>8.4</td><td>47.2</td><td>London</td><td>GB</td><td>gcpv</td><td>3143916060674</td><td>51.5150522</td><td>-0.159239</td><td>2 Wallenberg Place Westminster Borough London W1H 7TN United Kingdom</td><td>2016-10-10T00:00:00Z</td><td>null</td><td>null</td><td>null</td><td>2016-10-10</td></tr><tr><td>DoubleTree by Hilton London West End</td><td>8.4</td><td>47.2</td><td>London</td><td>GB</td><td>gcpv</td><td>3221225472004</td><td>51.5201065</td><td>-0.1221393</td><td>92 Southampton Row Camden London WC1B 4BH United Kingdom</td><td>2016-10-10T00:00:00Z</td><td>null</td><td>null</td><td>null</td><td>2016-10-10</td></tr><tr><td>Montcalm Royal London House City of London</td><td>8.4</td><td>47.2</td><td>London</td><td>GB</td><td>gcpv</td><td>3332894621696</td><td>51.5218066</td><td>-0.0856081</td><td>22 25 Finsbury Square City Islington London EC2A 1DX United Kingdom</td><td>2016-10-10T00:00:00Z</td><td>null</td><td>null</td><td>null</td><td>2016-10-10</td></tr><tr><td>Radisson Blu Edwardian Berkshire</td><td>8.4</td><td>47.2</td><td>London</td><td>GB</td><td>gcpv</td><td>2508260900866</td><td>51.5146025</td><td>-0.1481978</td><td>350 Oxford Street Westminster Borough London W1C 1BY United Kingdom</td><td>2016-10-10T00:00:00Z</td><td>null</td><td>null</td><td>null</td><td>2016-10-10</td></tr><tr><td>Great St Helen Hotel</td><td>8.4</td><td>47.2</td><td>London</td><td>GB</td><td>gcpv</td><td>2362232012803</td><td>51.5149583</td><td>-0.0823869</td><td>36 Great st Helens City of London London EC3A 6AP United Kingdom</td><td>2016-10-10T00:00:00Z</td><td>null</td><td>null</td><td>null</td><td>2016-10-10</td></tr><tr><td>Norfolk Towers Paddington</td><td>8.4</td><td>47.2</td><td>Paddington</td><td>GB</td><td>gcpv</td><td>3358664425476</td><td>51.5162883</td><td>-0.1721078</td><td>34 Norfolk Place Paddington Westminster Borough London W2 1QW United Kingdom</td><td>2016-10-10T00:00:00Z</td><td>null</td><td>null</td><td>n ...

# %%
# ----------------------------------------
# 7) Aggregate: distinct hotels & rounded temps
# ----------------------------------------
stream = (
    raw_stream
      .withColumn("wthr_date", col("wthr_date").cast(TimestampType()))
      .withColumn("date",      to_date(col("wthr_date")))
      .withWatermark("wthr_date", "1 day")
)

aggregated = (
    stream
      .groupBy("city", "date")
      .agg(
          approx_count_distinct("id") .alias("distinct_hotels"),
          round(avg("avg_tmpr_c"), 2) .alias("avg_temp_c"),
          round(max("avg_tmpr_c"), 2) .alias("max_temp_c"),
          round(min("avg_tmpr_c"), 2) .alias("min_temp_c")
      )
)
print("Aggregated schema:")
aggregated.printSchema()

# %%
display(aggregated)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th
td>21.9</td><td>21.9</td></tr><tr><td>Woodburn</td><td>2017-09-28</td><td>1</td><td>18.6</td><td>18.6</td><td>18.6</td></tr><tr><td>Sacramento</td><td>2017-08-06</td><td>1</td><td>22.3</td><td>22.3</td><td>22.3</td></tr><tr><td>Chattanooga</td><td>2017-09-11</td><td>2</td><td>14.1</td><td>14.1</td><td>14.1</td></tr><tr><td>Towson</td><td>2017-08-30</td><td>1</td><td>19.2</td><td>19.2</td><td>19.2</td></tr><tr><td>Boulogne Billancourt</td><td>2017-08-15</td><td>1</td><td>19.4</td><td>19.4</td><td>19.4</td></tr><tr><td>Crescent City</td><td>2017-09-05</td><td>1</td><td>17.0</td><td>17.0</td><td>17.0</td></tr><tr><td>Groveland</td><td>2017-09-10</td><td>1</td><td>14.6</td><td>14.6</td><td>14.6</td></tr><tr><td>Hartford</td><td>2017-09-05</td><td>2</td><td>23.1</td><td>23.1</td><td>23.1</td></tr><tr><td>Bull Shoals</td><td>2017-09-14</td><td>1</td><td>21.4</td><td>21.4</td><td>21.4</td></tr><tr><td>Providence</td><td>2017-09-13</td><td>1</td><td>20.6</td><td>20.6</td><td>20.6</td></tr><tr><td>Winston Salem</td><td>2017-08-23</td><td>1</td><td>25.7</td><td>25.7</td><td>25.7</td></tr><tr><td>Newton</td><td>2017-09-26</td><td>1</td><td> ...

# %%
# ----------------------------------------
# 8) Start Streaming Queries (separate checkpoints)
# ----------------------------------------
# 8a) Console sink (for debug)
console_q = (
    aggregated.writeStream
      .outputMode("complete")
      .format("console")
      .option("truncate", False)
      .option("checkpointLocation", console_ckpt)
      .trigger(processingTime="20 seconds")
      .start()
)

# %%
display(console_q)

# %%
# 8b) Delta Lake sink (for downstream queries & viz)
delta_q = (
    aggregated.writeStream
      .outputMode("complete")
      .format("delta")
      .option("path",               delta_path)
      .option("checkpointLocation", delta_ckpt)
      .trigger(processingTime="20 seconds")
      .start()
)

# %%
# ----------------------------------------
# 9) Read Back Delta & Register View
# ----------------------------------------
agg_batch_df = spark.read.format("delta").load(delta_path)
agg_batch_df.createOrReplaceTempView("agg_view")

# %%
# ----------------------------------------
# 10) Identify Top 10 Cities by Hotel Count
# ----------------------------------------
top10_df = spark.sql("""
  SELECT city, SUM(distinct_hotels) AS total_hotels
    FROM agg_view
   GROUP BY city
   ORDER BY total_hotels DESC
   LIMIT 10
""")
display(top10_df)
top_cities = [r["city"] for r in top10_df.collect()]
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>total_hotels</th></tr></thead><tbody><tr><td>Paris</td><td>3421</td></tr><tr><td>London</td><td>2395</td></tr><tr><td>Milan</td><td>1464</td></tr><tr><td>Amsterdam</td><td>566</td></tr><tr><td>Barcelona</td><td>428</td></tr><tr><td>Paddington</td><td>133</td></tr><tr><td>Springfield</td><td>50</td></tr><tr><td>Houston</td><td>42</td></tr><tr><td>Memphis</td><td>33</td></tr><tr><td>Columbus</td><td>30</td></tr></tbody></table></div>

# %%
df_city.explain(True)

# %%
from pyspark.sql.functions import col, to_date

for city in top_cities:
    full = spark.sql(f"""
      SELECT date,
             distinct_hotels,
             avg_temp_c,
             max_temp_c,
             min_temp_c
        FROM agg_view
       WHERE city = '{city}'
       ORDER BY date
    """)
    
    # get first 3 dates
    first3 = [r.date for r in full.select("date")
                          .orderBy("date")
                          .limit(3)
                          .collect()]
    
    small = full.where(col("date").isin(first3))
    
    # unpivot with all doubles
    unpivot = small.selectExpr(
      "date",
      """
      stack(
        4,
        'Hotels',          cast(distinct_hotels as double),
        'Avg Temperature', avg_temp_c,
        'Max Temperature', max_temp_c,
        'Min Temperature', min_temp_c
      ) as (metric, value)
      """
    )
    
    displayHTML(f"<h2 style='margin-top:2em'>{city}</h2>")
    display(unpivot)
# Out:
# <h2 style='margin-top:2em'>Paris</h2>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>metric</th><th>value</th></tr></thead><tbody><tr><td>2016-10-03</td><td>Hotels</td><td>228.0</td></tr><tr><td>2016-10-09</td><td>Hotels</td><td>228.0</td></tr><tr><td>2016-10-03</td><td>Avg Temperature</td><td>10.7</td></tr><tr><td>2016-10-09</td><td>Avg Temperature</td><td>8.7</td></tr><tr><td>2016-10-03</td><td>Max Temperature</td><td>10.7</td></tr><tr><td>2016-10-09</td><td>Max Temperature</td><td>8.7</td></tr><tr><td>2016-10-03</td><td>Min Temperature</td><td>10.7</td></tr><tr><td>2016-10-09</td><td>Min Temperature</td><td>8.7</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.
# <h2 style='margin-top:2em'>London</h2>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>metric</th><th>value</th></tr></thead><tbody><tr><td>2016-10-09</td><td>Hotels</td><td>1.0</td></tr><tr><td>2016-10-10</td><td>Hotels</td><td>250.0</td></tr><tr><td>2016-10-09</td><td>Avg Temperature</td><td>13.6</td></tr><tr><td>2016-10-10</td><td>Avg Temperature</td><td>8.4</td></tr><tr><td>2016-10-09</td><td>Max Temperature</td><td>13.6</td></tr><tr><td>2016-10-10</td><td>Max Temperature</td><td>8.4</td></tr><tr><td>2016-10-09</td><td>Min Temperature</td><td>13.6</td></tr><tr><td>2016-10-10</td><td>Min Temperature</td><td>8.4</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.
# <h2 style='margin-top:2em'>Milan</h2>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>metric</th><th>value</th></tr></thead><tbody><tr><td>2016-10-06</td><td>Hotels</td><td>157.0</td></tr><tr><td>2016-10-16</td><td>Hotels</td><td>157.0</td></tr><tr><td>2016-10-06</td><td>Avg Temperature</td><td>12.1</td></tr><tr><td>2016-10-16</td><td>Avg Temperature</td><td>12.3</td></tr><tr><td>2016-10-06</td><td>Max Temperature</td><td>12.1</td></tr><tr><td>2016-10-16</td><td>Max Temperature</td><td>12.3</td></tr><tr><td>2016-10-06</td><td>Min Temperature</td><td>12.1</td></tr><tr><td>2016-10-16</td><td>Min Temperature</td><td>12.3</td></tr></tbody></table></div>
# <h2 style='margin-top:2em'>Amsterdam</h2>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>metric</th><th>value</th></tr></thead><tbody><tr><td>2016-10-02</td><td>Hotels</td><td>85.0</td></tr><tr><td>2017-08-03</td><td>Hotels</td><td>85.0</td></tr><tr><td>2016-10-02</td><td>Avg Temperature</td><td>13.7</td></tr><tr><td>2017-08-03</td><td>Avg Temperature</td><td>18.8</td></tr><tr><td>2016-10-02</td><td>Max Temperature</td><td>13.7</td></tr><tr><td>2017-08-03</td><td>Max Temperature</td><td>18.8</td></tr><tr><td>2016-10-02</td><td>Min Temperature</td><td>13.7</td></tr><tr><td>2017-08-03</td><td>Min Temperature</td><td>18.8</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.
# <h2 style='margin-top:2em'>Barcelona</h2>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>metric</th><th>value</th></tr></thead><tbody><tr><td>2016-10-03</td><td>Hotels</td><td>1.0</td></tr><tr><td>2016-10-13</td><td>Hotels</td><td>1.0</td></tr><tr><td>2016-10